# %%
from FuzzyMatcher import fuzzy_match

# %%
result_df = fuzzy_match(
    target_file="target_data.csv",
    source_file="source_data.csv",
    target_col="Messy_Company_Name",
    source_col="Official_Company_Name",
)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result_df = fuzzy_match(
#       2     target_file="target_data.csv",
#       3     source_file="source_data.csv",
#       4     target_col="Messy_Company_Name",
#
# File ~/Documents/Development/Deepseek/FuzzyMatcher.py:237, in fuzzy_match(target_file, source_file, target_col, source_col, scorer, threshold, preprocess_options, workers, batch_size, output_file)
#     234         raise ValueError(f"Unsupported file format: {filepath}. Use .csv, .xlsx, or .xls.")
#     236 df_target = load_file(target_file)
# --> 237 df_source = load_file(source_file)
#     239 if target_col not in df_target.columns:
#     240     raise ValueError(f"Target column '{target_col}' not found in {target_file}.")
#
# File ~/Documents/Development/Deepseek/FuzzyMatcher.py:230, in fuzzy_match.<locals>.load_file(filepath)
# ...
